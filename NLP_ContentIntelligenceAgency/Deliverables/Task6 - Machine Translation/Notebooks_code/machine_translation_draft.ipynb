# %% [markdown]
# ### Combining data from OPUS for model training

# %%
"""

import pandas as pd

# Пути к файлам (замените на свои локальные пути)
ru_file = "TED2020.en-ru.ru"
en_file = "TED2020.en-ru.en"
output_file = "TED2020_translations.xlsx"

# Читаем файлы построчно
with open(ru_file, "r", encoding="utf-8") as f:
    ru_sentences = f.readlines()

with open(en_file, "r", encoding="utf-8") as f:
    en_sentences = f.readlines()

# Проверяем, что количество строк совпадает
if len(ru_sentences) != len(en_sentences):
    print("Ошибка: Файлы содержат разное количество строк!")
else:
    print(f"Загружено {len(ru_sentences)} пар предложений.")

# Создаём DataFrame
df = pd.DataFrame({"Russian": [s.strip() for s in ru_sentences], 
                   "English": [s.strip() for s in en_sentences]})

# Сохраняем в Excel
df.to_excel(output_file, index=False, engine="openpyxl")

print(f"🎉 Данные успешно сохранены в файл {output_file}")"

"""

# %% [markdown]
# ### Data preparing

# %%
"""

import pandas as pd
from sklearn.model_selection import train_test_split

# Load dataset
df = pd.read_excel("TED2020_translations.xlsx")

# Split into train, validation, and test sets
train, temp = train_test_split(df, test_size=0.2, random_state=42)
val, test = train_test_split(temp, test_size=0.5, random_state=42)

# Save datasets as Excel files
train.to_excel("train.xlsx", index=False, engine="openpyxl")
val.to_excel("val.xlsx", index=False, engine="openpyxl")
test.to_excel("test.xlsx", index=False, engine="openpyxl")

print(f"Data prepared and saved: train({len(train)}), val({len(val)}), test({len(test)})")"

"""
# Out:
# Data prepared and saved: train(312011), val(39001), test(39002)

# %% [markdown]
# ### Cleaning the data

# %%
import pandas as pd

# Load training and validation data from Excel
train_data = pd.read_excel("train.xlsx", engine="openpyxl")
val_data = pd.read_excel("val.xlsx", engine="openpyxl")

# Drop NaN values and convert everything to strings
train_data = train_data.dropna().astype(str)
val_data = val_data.dropna().astype(str)

# Save cleaned data (optional step for debugging)
train_data.to_excel("train_cleaned.xlsx", index=False, engine="openpyxl")
val_data.to_excel("val_cleaned.xlsx", index=False, engine="openpyxl")

print("Data cleaned and saved as train_cleaned.xlsx & val_cleaned.xlsx")
# Out:
# Data cleaned and saved as train_cleaned.xlsx & val_cleaned.xlsx

# %% [markdown]
# ### Train the MarianMT Model

# %%
#!pip install transformers datasets torch sentencepiece
# Out:
# Requirement already satisfied: transformers in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (4.46.3)
# Requirement already satisfied: datasets in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (3.1.0)
# Requirement already satisfied: torch in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (2.4.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.2.0-cp38-cp38-win_amd64.whl.metadata (8.3 kB)
# Requirement already satisfied: filelock in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from transformers) (0.29.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from transformers) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from transformers) (0.5.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from transformers) (4.67.0)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from datasets) (2.0.0)
# Requirement already satisfied: xxhash in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2024.9.0)
# Requirement already satisfied: aiohttp in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from datasets) (3.10.11)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from aiohttp->datasets) (1.15.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from aiohttp->datasets) (5.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from requests->transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from requests->transformers) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from pandas->datasets) (2024.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\artjo\anaconda3\envs\block_b\lib\site-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets) (0.2.0)
# Downloading sentencepiece-0.2.0-cp38-cp38-win_amd64.whl (991 kB)
#    ---------------------------------------- 0.0/991.7 kB ? eta -:--:--
#    --------------------------------------- 991.7/991.7 kB 11.6 MB/s eta 0:00:00
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.2.0

# %%
#!pip install transformers[torch] accelerate>=0.26.0

# %%
import pandas as pd
from transformers import MarianMTModel, MarianTokenizer, Seq2SeqTrainer, Seq2SeqTrainingArguments
from datasets import Dataset

# Load cleaned training and validation data from Excel
train_data = pd.read_excel("train_cleaned.xlsx", engine="openpyxl")
val_data = pd.read_excel("val_cleaned.xlsx", engine="openpyxl")

# Convert Pandas DataFrame to Dataset format
train_dataset = Dataset.from_pandas(train_data)
val_dataset = Dataset.from_pandas(val_data)

# Load the MarianMT model and tokenizer
model_name = "Helsinki-NLP/opus-mt-ru-en"
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)

# Preprocessing function for tokenization
def preprocess_function(examples):
    inputs = tokenizer(examples["Russian"], max_length=128, truncation=True, padding="max_length")
    targets = tokenizer(examples["English"], max_length=128, truncation=True, padding="max_length")
    inputs["labels"] = targets["input_ids"]
    return inputs

# Apply tokenization with batch processing
train_dataset = train_dataset.map(preprocess_function, batched=True)
val_dataset = val_dataset.map(preprocess_function, batched=True)

# Define training arguments
training_args = Seq2SeqTrainingArguments(
    output_dir=".",
    evaluation_strategy="epoch",
    save_strategy="epoch",
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    logging_dir="./logs",
    logging_steps=10,
    save_total_limit=2
)

# Initialize Trainer
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset
)

# Start training
trainer.train()

# Save trained model
model.save_pretrained(".")
tokenizer.save_pretrained(".")

print("Training completed! Model saved")
# Out:
# c:\Users\artjo\anaconda3\envs\block_b\lib\site-packages\transformers\models\marian\tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Map: 100%|██████████| 309030/309030 [02:30<00:00, 2050.64 examples/s]
# Map: 100%|██████████| 38613/38613 [00:18<00:00, 2050.05 examples/s]
# c:\Users\artjo\anaconda3\envs\block_b\lib\site-packages\transformers\training_args.py:1568: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 43
#      30 training_args = Seq2SeqTrainingArguments(
#      31     output_dir=".",
#      32     evaluation_strategy="epoch",
#    (...)
#      39     save_total_limit=2
#      40 )
#      42 # Initialize Trainer
# ---> 43 trainer = Seq2SeqTrainer(
#      44     model=model,
#      45     args=training_args,
#      46     train_dataset=train_dataset,
#      47     eval_dataset=val_dataset
#      48 )
#      50 # Start training
#      51 trainer.train()
#
# File c:\Users\artjo\anaconda3\envs\block_b\lib\site-packages\transformers\utils\deprecation.py:165, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     161 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS):
#     162     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     163     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 165 return func(*args, **kwargs)
#
# File c:\Users\artjo\anaconda3\envs\block_b\lib\site-packages\transformers\trainer_seq2seq.py:72, in Seq2SeqTrainer.__init__(self, model, args, data_collator, train_dataset, eval_dataset, processing_class, model_init, compute_metrics, callbacks, optimizers, preprocess_logits_for_metrics)
#      55 @deprecate_kwarg("tokenizer", new_name="processing_class", version="5.0.0", raise_if_both_names=True)
#      56 def __init__(
#      57     self,
#    (...)
#      70     preprocess_logits_for_metrics: Optional[Callable[[torch.Tensor, torch.Tensor], torch.Tensor]] = None,
#      71 ):
# ---> 72     super().__init__(
#      73         model=model,
#      74         args=args,
#      75         data_collator=data_collator,
#      76         train_dataset=train_dataset,
#      77         eval_dataset=eval_dataset,
#      78         processing_class=processing_class,
#      79         model_init=model_init,
#      80         compute_metrics=compute_metrics,
#      81         callbacks=callbacks,
#      82         optimizers=optimizers,
#      83         preprocess_logits_for_metrics=preprocess_logits_for_metrics,
#      84     )
#      86     # Override self.model.generation_config if a GenerationConfig is specified in args.
#      87     # Priority: args.generation_config > model.generation_config > default GenerationConfig.
#      88     if self.args.generation_config is not None:
#
# File c:\Users\artjo\anaconda3\envs\block_b\lib\site-packages\transformers\utils\deprecation.py:165, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     161 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS):
#     162     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     163     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 165 return func(*args, **kwargs)
#
# File c:\Users\artjo\anaconda3\envs\block_b\lib\site-packages\transformers\trainer.py:630, in Trainer.__init__(self, model, args, data_collator, train_dataset, eval_dataset, processing_class, model_init, compute_loss_func, compute_metrics, callbacks, optimizers, preprocess_logits_for_metrics)
#     628 default_callbacks = DEFAULT_CALLBACKS + get_reporting_integration_callbacks(self.args.report_to)
#     629 callbacks = default_callbacks if callbacks is None else default_callbacks + callbacks
# --> 630 self.callback_handler = CallbackHandler(
#     631     callbacks, self.model, self.processing_class, self.optimizer, self.lr_scheduler
#     632 )
#     633 self.add_callback(PrinterCallback if self.args.disable_tqdm else DEFAULT_PROGRESS_CALLBACK)
#     635 # Will be set to True by `self._setup_loggers()` on first call to `self.log()`.
#
# File c:\Users\artjo\anaconda3\envs\block_b\lib\site-packages\transformers\trainer_callback.py:411, in CallbackHandler.__init__(self, callbacks, model, processing_class, optimizer, lr_scheduler)
#     409 self.callbacks = []
#     410 for cb in callbacks:
# --> 411     self.add_callback(cb)
#     412 self.model = model
#     413 self.processing_class = processing_class
#
# File c:\Users\artjo\anaconda3\envs\block_b\lib\site-packages\transformers\trainer_callback.py:428, in CallbackHandler.add_callback(self, callback)
#     427 def add_callback(self, callback):
# --> 428     cb = callback() if isinstance(callback, type) else callback
#     429     cb_class = callback if isinstance(callback, type) else callback.__class__
#     430     if cb_class in [c.__class__ for c in self.callbacks]:
#
# File c:\Users\artjo\anaconda3\envs\block_b\lib\site-packages\transformers\integrations\integration_utils.py:770, in WandbCallback.__init__(self)
#     768     raise RuntimeError("WandbCallback requires wandb to be installed. Run `pip install wandb`.")
#     769 if has_wandb:
# --> 770     import wandb
#     772     self._wandb = wandb
#     773 self._initialized = False
#
# File c:\Users\artjo\anaconda3\envs\block_b\lib\site-packages\wandb\__init__.py:21
#      18 # This needs to be early as other modules call it.
#      19 from wandb.errors.term import termsetup, termlog, termerror, termwarn
# ---> 21 from wandb import sdk as wandb_sdk
#      23 import wandb
#      25 wandb.wandb_lib = wandb_sdk.lib  # type: ignore
#
# File c:\Users\artjo\anaconda3\envs\block_b\lib\site-packages\wandb\sdk\__init__.py:28
#      26 from .wandb_alerts import AlertLevel
#      27 from .wandb_config import Config
# ---> 28 from .wandb_init import _attach, init
#      29 from .wandb_login import login
#      30 from .wandb_require import require
#
# File c:\Users\artjo\anaconda3\envs\block_b\lib\site-packages\wandb\sdk\wandb_init.py:40
#      37 from wandb.sdk.lib.paths import StrPath
#      38 from wandb.util import _is_artifact_representation
# ---> 40 from . import wandb_login, wandb_setup
#      41 from .backend.backend import Backend
#      42 from .lib import SummaryDisabled, filesystem, module, printer, telemetry
#
# File c:\Users\artjo\anaconda3\envs\block_b\lib\site-packages\wandb\sdk\wandb_login.py:19
#      17 from .internal.internal_api import Api
#      18 from .lib import apikey
# ---> 19 from .wandb_settings import Settings
#      22 def _handle_host_wandb_setting(host: Optional[str], cloud: bool = False) -> None:
#      23     """Write the host parameter to the global settings file.
#      24
#      25     This takes the parameter from wandb.login or wandb login for use by the
#      26     application's APIs.
#      27     """
#
# File c:\Users\artjo\anaconda3\envs\block_b\lib\site-packages\wandb\sdk\wandb_settings.py:25
#      22     from typing_extensions import Self
#      24 from google.protobuf.wrappers_pb2 import BoolValue, DoubleValue, Int32Value, StringValue
# ---> 25 from pydantic import (
#      26     BaseModel,
#      27     ConfigDict,
#      28     Field,
#      29     computed_field,
#      30     field_validator,
#      31     model_validator,
#      32 )
#      33 from pydantic_core import SchemaValidator, core_schema
#      35 import wandb
#
# ImportError: cannot import name 'computed_field' from 'pydantic' (c:\Users\artjo\anaconda3\envs\block_b\lib\site-packages\pydantic\__init__.cp38-win_amd64.pyd)
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
